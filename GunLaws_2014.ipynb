# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
df = pd.read_html('/Users/garimajain/Desktop/GunLaws2014.html')

# %%
df1 = df[0]

# %%
del df1['Unnamed: 0']

# %%
df1.columns = ['Rank','State', 'State Laws Grade', 'Death Rate Per 100k', 'New Smart Gun Laws' ]

# %%
df1['Year'] = 2014

# %%
df1
# Out:
#     Rank           State State Laws Grade  Death Rate Per 100k  \
# 0      1      California               A-                   42
# 1      2     Connecticut               A-                   45
# 2      3      New Jersey               A-                   46
# 3      4        Maryland               A-                   33
# 4      5        New York               A-                   47
# 5      6   Massachusetts               A-                   50
# 6      7          Hawaii               B+                   49
# 7      8        Illinois               B+                   38
# 8      9    Rhode Island               B+                   48
# 9     10        Delaware               B-                   30
# 10    11      Washington               B-                   35
# 11    12       Minnesota                C                   44
# 12    13    Pennsylvania                C                   26
# 13    14        Michigan                C                   22
# ...

# %%
df1.to_csv('GunLaws_2014.csv', index=False, encoding='utf-8')
