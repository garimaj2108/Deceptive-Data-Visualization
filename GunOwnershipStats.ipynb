# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/garimajain/Desktop/GunOwnershipStatistics.csv')

# %%
del df['Forcible rape (per 100K) 2013']

# %%
del df['Murder and nonnegligent manslaughter (per 100K) 2013']

# %%
del df['Robbery (per 100K) 2013']

# %%
del df['Larceny (per 100K) 2013']

# %%
del df['Motor Theft (per 100K) 2013']

# %%
df
# Out:
#               State Name  Gun Murder Rate per 100K (2010)  \
# 0                Alabama                              2.8
# 1                 Alaska                              2.7
# 2                Arizona                              3.6
# 3               Arkansas                              3.2
# 4             California                              3.4
# 5               Colorado                              1.3
# 6            Connecticut                              2.7
# 7               Delaware                              4.2
# 8   District of Columbia                             16.5
# 9                Florida                              3.9
# 10               Georgia                              3.8
# 11                Hawaii                              0.5
# 12                 Idaho                              0.8
# 13              Illinois                              2.8
# 14               Indiana                              2.2
# 15                  Iowa                              0.7
# 16                Kansas                              2.2
# 17              Kentucky                              2.7
# 18             Louisiana                              7.7
# 19                 Maine                              0.8
# 20              Maryland                              5.1
# 21         Massachusetts                              1.8
# 22              Michigan                              4.2
# 23             Minnesota                              1.0
# 24           Mississippi                              4.0
# 25              Missouri                              5.4
# 26               Montana                              1.2
# 27              Nebraska                              1.8
# 28                Nevada                              3.1
# 29         New Hampshire                              0.4
# 30            New Jersey                              2.8
# 31            New Mexico                              3.3
# 32              New York                              2.7
# 33        North Carolina                              3.0
# 34          North Dakota                              0.6
# 35                  Ohio                              2.7
# 36              Oklahoma                              3.0
# 37                Oregon                              0.9
# 38          Pennsylvania                              3.6
# 39          Rhode Island                              1.5
# 40        South Carolina                              4.5
# 41          South Dakota                              1.0
# 42             Tennessee                              3.5
# 43                 Texas                              3.2
# 44                  Utah                              0.8
# 45               Vermont                              0.3
# 46              Virginia                              3.1
# 47            Washington                              1.4
# 48         West Virginia                              1.5
# 49             Wisconsin                              1.7
# 50               Wyoming                              0.9
#
#    Gun Ownership (2007)  Violent Crime  (per 100,000) 2013  \
# 0                 51.7%                              449.9
# 1                 57.8%                              603.2
# 2                 31.1%                              428.9
# 3                 55.3%                              469.1
# 4                 21.3%                              423.1
# 5                 34.7%                              308.9
# 6                 16.7%                              283.0
# 7                 25.5%                              547.4
# 8                  3.6%                             1243.7
# 9                 24.5%                              487.1
# 10                40.3%                              378.9
# 11                 6.7%                              239.2
# 12                55.3%                              207.9
# 13                20.2%                              414.8
# 14                39.1%                              345.7
# 15                42.9%                              263.9
# 16                42.1%                              354.6
# 17                47.7%                              222.6
# 18                44.1%                              496.9
# 19                40.5%                              122.7
# 20                21.3%                              476.8
# 21                12.6%                              405.5
# 22                38.4%                              454.5
# 23                41.7%                              230.9
# 24                55.3%                              260.8
# 25                41.7%                              450.9
# 26                57.7%                              272.2
# 27                38.6%                              259.4
# 28                33.8%                              607.6
# 29                  30%                              187.9
# 30                12.3%                              290.2
# 31                34.8%                              559.1
# 32                  18%                              406.8
# 33                41.3%                              353.4
# 34                50.7%                              244.7
# 35                32.4%                              299.7
# 36                42.9%                              469.3
# 37                39.8%                              247.6
# 38                34.7%                              348.7
# 39                12.8%                              252.4
# 40                42.3%                              558.8
# 41                56.6%                              321.8
# 42                43.9%                              643.6
# 43                35.9%                              408.6
# 44                43.9%                              205.8
# 45                  42%                              142.6
# 46                35.1%                              190.1
# 47                33.1%                              295.6
# 48                55.4%                              316.3
# 49                44.4%                              280.5
# 50                59.7%                              201.4
#
#     Aggravated assault  (per 100K) 2013  Property Crime  (per 100K) 2013  \
# 0                                 311.8                           3502.2
# 1                                 433.2                           2739.4
# 2                                 276.0                           3539.2
# 3                                 342.3                           3660.1
# 4                                 248.9                           2758.7
# 5                                 199.6                           2684.7
# 6                                 150.6                           2140.0
# 7                                 352.0                           3340.9
# 8                                 554.1                           4860.8
# 9                                 330.9                           3276.7
# 10                                226.0                           3410.6
# 11                                141.9                           3075.2
# 12                                160.9                           1983.5
# 13                                230.0                           2578.7
# 14                                214.6                           3029.2
# 15                                202.8                           2271.8
# 16                                263.2                           3143.2
# 17                                108.4                           2552.9
# 18                                342.0                           3540.6
# 19                                 61.0                           2509.9
# 20                                277.2                           2753.5
# 21                                280.4                           2153.0
# 22                                295.5                           2530.5
# 23                                134.0                           2568.3
# 24                                149.4                           2811.0
# 25                                323.4                           3314.4
# 26                                212.8                           2583.7
# 27                                157.4                           2754.9
# 28                                391.1                           2809.4
# 29                                117.0                           2324.0
# 30                                145.7                           2047.3
# 31                                419.1                           3600.7
# 32                                242.3                           1922.0
# 33                                231.8                           3369.5
# 34                                183.1                           2010.1
# 35                                131.7                           3117.4
# 36                                337.3                           3401.0
# 37                                154.1                           3224.2
# 38                                194.4                           2166.3
# 39                                153.9                           2572.3
# 40                                421.4                           3822.2
# 41                                229.7                           2060.1
# 42                                479.6                           3371.4
# 43                                258.0                           3361.8
# 44                                132.5                           2991.8
# 45                                104.2                           2398.7
# 46                                111.1                           2162.1
# 47                                177.5                           3658.6
# 48                                244.6                           2364.9
# 49                                175.5                           2453.8
# 50                                161.7                           2293.8
#
#     Burglary  (per 100K) 2013
# 0                       984.7
# 1                       403.3
# 2                       807.8
# 3                      1081.3
# 4                       646.1
# 5                       504.2
# 6                       409.7
# 7                       803.7
# 8                       556.5
# 9                       794.9
# 10                      874.9
# 11                      573.1
# 12                      450.3
# 13                      552.2
# 14                      728.3
# 15                      556.1
# 16                      650.3
# 17                      675.4
# 18                      915.7
# 19                      561.3
# 20                      573.2
# 21                      519.7
# 22                      664.4
# 23                      471.8
# 24                      940.6
# 25                      705.2
# 26                      387.4
# 27                      470.8
# 28                      801.8
# 29                      412.2
# 30                      477.6
# 31                     1025.3
# 32                      329.9
# 33                     1018.5
# 34                      339.8
# 35                      895.9
# 36                      936.6
# 37                      561.7
# 38                      445.5
# 39                      566.4
# 40                      954.5
# 41                      391.0
# 42                      870.2
# 43                      785.9
# 44                      453.3
# 45                      633.4
# 46                      360.5
# 47                      880.5
# 48                      608.5
# 49                      488.0
# 50                      368.7

# %%
df.to_csv('GunOwnershipStats.csv', index=False, encoding='utf-8')
