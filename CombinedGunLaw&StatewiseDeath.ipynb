# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/garimajain/Desktop/Combined_Statewise_deaths_2015.csv')

# %%
df
# Out:
#                    State  First Year  Last Year Cause of Death  Deaths  \
# 0                Alabama        2015       2015        Firearm     958
# 1                 Alaska        2015       2015        Firearm     177
# 2                Arizona        2015       2015        Firearm     970
# 3               Arkansas        2015       2015        Firearm     520
# 4             California        2015       2015        Firearm    3095
# 5               Colorado        2015       2015        Firearm     701
# 6            Connecticut        2015       2015        Firearm     189
# 7               Delaware        2015       2015        Firearm     112
# 8   District of Columbia        2015       2015        Firearm     120
# 9                Florida        2015       2015        Firearm    2559
# 10               Georgia        2015       2015        Firearm    1448
# 11                Hawaii        2015       2015        Firearm      55
# ...

# %%
del df['Last Year']

# %%
del df['Age-Adjusted Rate']

# %%
del df['Unnamed: 12']

# %%
df
# Out:
#                    State  First Year Cause of Death  Deaths  Population  \
# 0                Alabama        2015        Firearm     958     4858979
# 1                 Alaska        2015        Firearm     177      738432
# 2                Arizona        2015        Firearm     970     6828065
# 3               Arkansas        2015        Firearm     520     2978204
# 4             California        2015        Firearm    3095    39144818
# 5               Colorado        2015        Firearm     701     5456574
# 6            Connecticut        2015        Firearm     189     3590886
# 7               Delaware        2015        Firearm     112      945934
# 8   District of Columbia        2015        Firearm     120      672228
# 9                Florida        2015        Firearm    2559    20271272
# 10               Georgia        2015        Firearm    1448    10214860
# 11                Hawaii        2015        Firearm      55     1431603
# ...

# %%
df.to_csv('CombinedGunLaw&StatewiseDeath.csv', index=False, encoding='utf-8')
