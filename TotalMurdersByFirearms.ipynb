# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/garimajain/Desktop/Homicide/Table_20_Murder_by_State_Types_of_Weapons_2014.csv')

# %%
df.drop(df.index[[0,1]])
# Out:
#                                              Table 20       Unnamed: 1  \
# 2                                               State  Total\nmurders1
# 3                                            Alabama3                1
# 4                                              Alaska               41
# 5                                             Arizona              258
# 6                                            Arkansas              154
# 7                                          California            1,697
# 8                                            Colorado              149
# 9                                         Connecticut               83
# 10                                           Delaware               54
# 11                               District of Columbia              105
# 12                                            Georgia              540
# 13                                             Hawaii                5
# ...

# %%
df1 = df.drop(['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'], axis=1)

# %%
df1.drop(df1.index[[0,1]])
# Out:
#                                              Table 20       Unnamed: 1  \
# 2                                               State  Total\nmurders1
# 3                                            Alabama3                1
# 4                                              Alaska               41
# 5                                             Arizona              258
# 6                                            Arkansas              154
# 7                                          California            1,697
# 8                                            Colorado              149
# 9                                         Connecticut               83
# 10                                           Delaware               54
# 11                               District of Columbia              105
# 12                                            Georgia              540
# 13                                             Hawaii                5
# ...

# %%
df1.columns = ['State', 'Total Murders', 'Total Firearms']

# %%
df2 = df1.drop(df1.index[[0,1,2]])

# %%
df2.drop(df2.index[[55,56,57]])
# Out:
#                                                 State Total Murders  \
# 3                                            Alabama3             1
# 4                                              Alaska            41
# 5                                             Arizona           258
# 6                                            Arkansas           154
# 7                                          California         1,697
# 8                                            Colorado           149
# 9                                         Connecticut            83
# 10                                           Delaware            54
# 11                               District of Columbia           105
# 12                                            Georgia           540
# 13                                             Hawaii             5
# 14                                              Idaho            30
# 15                                          Illinois3           428
# ...

# %%
df2.to_csv('TotalMurdersByFirearms.csv', index=False, encoding='utf-8')
