# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/garimajain/Desktop/ConsolidatedDataTable.csv')

# %%
del df['RANKING OF GUN DEATH (The Smaller, The Better)']

# %%
del df['STATE ABBREVIATIONS']

# %%
df[:-3]
# Out:
#               STATE NAME  POPULATION IN 2014  GUN DEATH RATE (2014)  \
# 0   District of Columbia            658893.0                  13.05
# 1             New Jersey           8938175.0                   5.30
# 2                 Hawaii           1419561.0                   2.60
# 3               New York          19746227.0                   4.20
# 4           Rhode Island           1055173.0                   2.90
# 5               Maryland           5976407.0                   9.00
# 6          Massachusetts           6745408.0                   3.20
# 7               Nebraska           1881503.0                   9.40
# 8             California          38802500.0                   7.40
# 9                   Iowa           3107126.0                   7.40
# 10                Nevada           2839099.0                  14.70
# 11              Michigan           9909877.0                  11.10
# 12              Delaware            935614.0                  11.10
# ...

# %%
df.to_csv('2014GunDeathAbs_num.csv', index=False, encoding='utf-8')
