# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
df = pd.read_html('/Users/garimajain/Desktop/GunLaws2015.html')

# %%
df1 = df[0]

# %%
df1.columns = ['Rank','State', 'State Laws Grade', 'Death Rate Per 100k', 'New Smart Gun Laws' ]

# %%
df1['Year'] = 2015

# %%
df1
# Out:
#     Rank           State State Laws Grade  Death Rate Per 100k  \
# 0      1      California               A-                   42
# 1      2     Connecticut               A-                   47
# 2      3      New Jersey               A-                   45
# 3      4        Maryland               A-                   36
# 4      5   Massachusetts               A-                   49
# 5      6        New York               A-                   48
# 6      7          Hawaii               B+                   50
# 7      8        Illinois               B+                   40
# 8      9    Rhode Island               B+                   46
# 9     10        Delaware                B                   32
# 10    11      Washington               B-                   39
# 11    12       Minnesota                C                   43
# 12    13    Pennsylvania                C                   27
# 13    14          Oregon                C                   28
# ...

# %%
df1.to_csv('GunLaws_2015.csv', index=False, encoding='utf-8')
