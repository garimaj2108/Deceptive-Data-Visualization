# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/garimajain/Desktop/Deceptive_Visualization/Deaths_by_gun_2015.csv')

# %%
del df['Operations']

# %%
del df['Address']

# %%
del df['City Or County']

# %%
Total_Killed = df['# Killed'].sum()

# %%
df.loc['Total_Killed'] = pd.Series(df['# Killed'].sum(), index = ['# Killed'])

# %%
Total_Injured = df['# Injured'].sum()

# %%
df.loc['Total_Injured'] = pd.Series(df['# Injured'].sum(), index = ['# Injured'])

# %%
df.columns.values['0'] = 'Incident Date'
# Out:
# /Users/garimajain/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   if __name__ == '__main__':

# %%
df
# Out:
#                    Incident Date           State  # Killed  # Injured
# 0              December 31, 2015       Louisiana       0.0        6.0
# 1              December 27, 2015       Tennessee       0.0        4.0
# 2              December 26, 2015    Pennsylvania       0.0        4.0
# 3              December 25, 2015         Florida       0.0        4.0
# 4              December 25, 2015         Alabama       0.0        4.0
# 5              December 21, 2015      California       0.0        4.0
# 6              December 20, 2015  North Carolina       1.0        4.0
# 7              December 20, 2015         Florida       1.0        4.0
# 8              December 20, 2015         Florida       0.0        4.0
# 9              December 13, 2015      California       1.0        3.0
# 10             December 13, 2015      California       0.0        4.0
# 11             December 12, 2015         Georgia       0.0        4.0
# ...

# %%
df.to_csv('shooting_2015.csv', index=False, encoding='utf-8')
