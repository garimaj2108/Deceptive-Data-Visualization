# %%
import glob, os
import pandas as pd

# %%
path =r'/Users/garimajain/Desktop/Deceptive_Visualization/GunLaws' # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))     # advisable to use os.path.join as this makes concatenation OS independent

df_from_each_file = (pd.read_csv(f) for f in all_files)
concatenated_df   = pd.concat(df_from_each_file, ignore_index=True)

# %%
concatenated_df
# Out:
#      Rank           State State Laws Grade  Death Rate Per 100k  \
# 0       1      California               A-                   42
# 1       2     Connecticut               A-                   45
# 2       3      New Jersey               A-                   46
# 3       4        Maryland               A-                   33
# 4       5        New York               A-                   47
# 5       6   Massachusetts               A-                   50
# 6       7          Hawaii               B+                   49
# 7       8        Illinois               B+                   38
# 8       9    Rhode Island               B+                   48
# 9      10        Delaware               B-                   30
# 10     11      Washington               B-                   35
# 11     12       Minnesota                C                   44
# 12     13    Pennsylvania                C                   26
# 13     14        Michigan                C                   22
# 14     15            Iowa               C-                   43
# 15     16        Colorado               C-                   20
# 16     17       Wisconsin               C-                   40
# 17     18          Oregon               D+                   28
# 18     19            Ohio                D                   27
# 19     20        Virginia                D                   32
# 20     21        Nebraska                D                   36
# 21     22   New Hampshire               D-                   41
# 22     23         Indiana               D-                   23
# 23     24           Maine                F                   37
# 24     24        Oklahoma                F                    8
# 25     24   West Virginia                F                   12
# 26     27         Georgia                F                   19
# 27     27    North Dakota                F                   31
# 28     29          Nevada                F                   18
# 29     29  North Carolina                F                   25
# ..    ...             ...              ...                  ...
# 120    21            Ohio                D                   26
# 121    21        Virginia                D                   34
# 122    23   New Hampshire                D                   40
# 123    24         Indiana               D-                   21
# 124    23  North Carolina               D-                   23
# 125    26         Florida                F                   25
# 126    27        Oklahoma                F                    8
# 127    27       Tennessee                F                   12
# 128    29         Georgia                F                   16
# 129    29      New Mexico                F                    7
# 130    29    North Dakota                F                   20
# 131    29  South Carolina                F                   10
# 132    29            Utah                F                   19
# 133    34           Texas                F                   28
# 134    34   West Virginia                F                   17
# 135    36           Maine                F                   36
# 136    37         Alabama                F                    3
# 137    38        Arkansas                F                   11
# 138    38         Montana                F                    6
# 139    40    South Dakota                F                   33
# 140    41         Vermont                F                   38
# 141    42        Kentucky                F                   13
# 142    43       Louisiana                F                    2
# 143    44          Alaska                F                    1
# 144    45         Wyoming                F                    4
# 145    46           Idaho                F                   15
# 146    47         Arizona                F                   18
# 147    48          Kansas                F                   31
# 148    48        Missouri                F                    9
# 149    50     Mississippi                F                    5
#
#     New Smart Gun Laws  Year
# 0                  yes  2014
# 1                  NaN  2014
# 2                  NaN  2014
# 3                  NaN  2014
# 4                  NaN  2014
# 5                  yes  2014
# 6                  yes  2014
# 7                  NaN  2014
# 8                  yes  2014
# 9                  NaN  2014
# 10                 yes  2014
# 11                 yes  2014
# 12                 NaN  2014
# 13                 NaN  2014
# 14                 NaN  2014
# 15                 NaN  2014
# 16                 NaN  2014
# 17                 NaN  2014
# 18                 NaN  2014
# 19                 NaN  2014
# 20                 NaN  2014
# 21                 NaN  2014
# 22                 NaN  2014
# 23                 NaN  2014
# 24                 yes  2014
# 25                 NaN  2014
# 26                 NaN  2014
# 27                 NaN  2014
# 28                 NaN  2014
# 29                 NaN  2014
# ..                 ...   ...
# 120                NaN  2016
# 121                NaN  2016
# 122                NaN  2016
# 123                NaN  2016
# 124                yes  2016
# 125                NaN  2016
# 126                NaN  2016
# 127                NaN  2016
# 128                NaN  2016
# 129                NaN  2016
# 130                NaN  2016
# 131                NaN  2016
# 132                NaN  2016
# 133                NaN  2016
# 134                NaN  2016
# 135                NaN  2016
# 136                NaN  2016
# 137                NaN  2016
# 138                NaN  2016
# 139                NaN  2016
# 140                NaN  2016
# 141                NaN  2016
# 142                NaN  2016
# 143                NaN  2016
# 144                NaN  2016
# 145                NaN  2016
# 146                NaN  2016
# 147                NaN  2016
# 148                NaN  2016
# 149                NaN  2016
#
# [150 rows x 6 columns]

# %%
concatenated_df.to_csv('ComprehensiveGunLawsData.csv', index=False, encoding='utf-8')
